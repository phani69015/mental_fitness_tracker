# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df1 = pd.read_csv("prevalence-by-mental-and-substance-use-disorder.csv")
df2 = pd.read_csv("mental-and-substance-use-as-share-of-disease.csv")
df1
df2
# Out:
#            Entity  Year  \
# 0     Afghanistan  1990
# 1     Afghanistan  1991
# 2     Afghanistan  1992
# 3     Afghanistan  1993
# 4     Afghanistan  1994
# ...           ...   ...
# 6835     Zimbabwe  2015
# 6836     Zimbabwe  2016
# 6837     Zimbabwe  2017
# 6838     Zimbabwe  2018
# 6839     Zimbabwe  2019
#
#       DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 0                                              1.696670
# 1                                              1.734281
# 2                                              1.791189
# 3                                              1.776779
# 4                                              1.712986
# ...                                                 ...
# 6835                                           2.193166
# 6836                                           2.279813
# 6837                                           2.364265
# 6838                                           2.472949
# 6839                                           2.525892
#
# [6840 rows x 3 columns]

# %%
df1.head()
# Out:
#         Entity  Year  \
# 0  Afghanistan  1990
# 1  Afghanistan  1991
# 2  Afghanistan  1992
# 3  Afghanistan  1993
# 4  Afghanistan  1994
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.721207
# 1                                           0.719952
# 2                                           0.718418
# 3                                           0.717452
# 4                                           0.717012
#
#    Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.131001
# 1                                           0.126395
# 2                                           0.121832
# 3                                           0.117942
# 4                                           0.114547
#
#    Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           4.835127
# 1                                           4.821765
# 2                                           4.801434
# 3                                           4.789363
# 4                                           4.784923
#
#    Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.454202
# 1                                           0.447112
# 2                                           0.441190
# 3                                           0.435581
# 4                                           0.431822
#
#    Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           5.125291
# 1                                           5.116306
# 2                                           5.106558
# 3                                           5.100328
# 4                                           5.099424
#
#    Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)
# 0                                           0.444036
# 1                                           0.444250
# 2                                           0.445501
# 3                                           0.445958
# 4                                           0.445779

# %%
df2.head(10)
# Out:
#         Entity  Year  \
# 0  Afghanistan  1990
# 1  Afghanistan  1991
# 2  Afghanistan  1992
# 3  Afghanistan  1993
# 4  Afghanistan  1994
# 5  Afghanistan  1995
# 6  Afghanistan  1996
# 7  Afghanistan  1997
# 8  Afghanistan  1998
# 9  Afghanistan  1999
#
#    DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 0                                           1.696670
# 1                                           1.734281
# 2                                           1.791189
# 3                                           1.776779
# 4                                           1.712986
# 5                                           1.738272
# 6                                           1.778098
# 7                                           1.781815
# 8                                           1.729402
# 9                                           1.850988

# %%
data=pd.merge(df1,df2)
data.head(10)
# Out:
#         Entity  Year  \
# 0  Afghanistan  1990
# 1  Afghanistan  1991
# 2  Afghanistan  1992
# 3  Afghanistan  1993
# 4  Afghanistan  1994
# 5  Afghanistan  1995
# 6  Afghanistan  1996
# 7  Afghanistan  1997
# 8  Afghanistan  1998
# 9  Afghanistan  1999
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
# 5                                           0.224713
# 6                                           0.223690
# 7                                           0.222424
# 8                                           0.221129
# 9                                           0.220065
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.721207
# 1                                           0.719952
# 2                                           0.718418
# 3                                           0.717452
# 4                                           0.717012
# 5                                           0.716686
# 6                                           0.716388
# 7                                           0.716143
# 8                                           0.716139
# 9                                           0.716323
#
#    Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.131001
# 1                                           0.126395
# 2                                           0.121832
# 3                                           0.117942
# 4                                           0.114547
# 5                                           0.111129
# 6                                           0.107786
# 7                                           0.103931
# 8                                           0.100343
# 9                                           0.097946
#
#    Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           4.835127
# 1                                           4.821765
# 2                                           4.801434
# 3                                           4.789363
# 4                                           4.784923
# 5                                           4.780851
# 6                                           4.777272
# 7                                           4.775242
# 8                                           4.777377
# 9                                           4.782067
#
#    Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.454202
# 1                                           0.447112
# 2                                           0.441190
# 3                                           0.435581
# 4                                           0.431822
# 5                                           0.428578
# 6                                           0.426393
# 7                                           0.423720
# 8                                           0.422491
# 9                                           0.421215
#
#    Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           5.125291
# 1                                           5.116306
# 2                                           5.106558
# 3                                           5.100328
# 4                                           5.099424
# 5                                           5.098495
# 6                                           5.100580
# 7                                           5.105474
# 8                                           5.113707
# 9                                           5.120480
#
#    Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.444036
# 1                                           0.444250
# 2                                           0.445501
# 3                                           0.445958
# 4                                           0.445779
# 5                                           0.445422
# 6                                           0.444837
# 7                                           0.443938
# 8                                           0.442665
# 9                                           0.441428
#
#    DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 0                                           1.696670
# 1                                           1.734281
# 2                                           1.791189
# 3                                           1.776779
# 4                                           1.712986
# 5                                           1.738272
# 6                                           1.778098
# 7                                           1.781815
# 8                                           1.729402
# 9                                           1.850988

# %% [markdown]
# DATA CLEANING STARTS

# %%
data.isnull().sum()
# Out:
# Entity                                                                                             0
# Year                                                                                               0
# Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)                           0
# Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)                        0
# Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)                        0
# Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)                       0
# Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)                      0
# Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)                    0
# Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)                   0
# DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)    0
# dtype: int64

# %%
data.head(10)
# Out:
#         Entity  Year  \
# 0  Afghanistan  1990
# 1  Afghanistan  1991
# 2  Afghanistan  1992
# 3  Afghanistan  1993
# 4  Afghanistan  1994
# 5  Afghanistan  1995
# 6  Afghanistan  1996
# 7  Afghanistan  1997
# 8  Afghanistan  1998
# 9  Afghanistan  1999
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
# 5                                           0.224713
# 6                                           0.223690
# 7                                           0.222424
# 8                                           0.221129
# 9                                           0.220065
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.721207
# 1                                           0.719952
# 2                                           0.718418
# 3                                           0.717452
# 4                                           0.717012
# 5                                           0.716686
# 6                                           0.716388
# 7                                           0.716143
# 8                                           0.716139
# 9                                           0.716323
#
#    Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.131001
# 1                                           0.126395
# 2                                           0.121832
# 3                                           0.117942
# 4                                           0.114547
# 5                                           0.111129
# 6                                           0.107786
# 7                                           0.103931
# 8                                           0.100343
# 9                                           0.097946
#
#    Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           4.835127
# 1                                           4.821765
# 2                                           4.801434
# 3                                           4.789363
# 4                                           4.784923
# 5                                           4.780851
# 6                                           4.777272
# 7                                           4.775242
# 8                                           4.777377
# 9                                           4.782067
#
#    Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.454202
# 1                                           0.447112
# 2                                           0.441190
# 3                                           0.435581
# 4                                           0.431822
# 5                                           0.428578
# 6                                           0.426393
# 7                                           0.423720
# 8                                           0.422491
# 9                                           0.421215
#
#    Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           5.125291
# 1                                           5.116306
# 2                                           5.106558
# 3                                           5.100328
# 4                                           5.099424
# 5                                           5.098495
# 6                                           5.100580
# 7                                           5.105474
# 8                                           5.113707
# 9                                           5.120480
#
#    Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.444036
# 1                                           0.444250
# 2                                           0.445501
# 3                                           0.445958
# 4                                           0.445779
# 5                                           0.445422
# 6                                           0.444837
# 7                                           0.443938
# 8                                           0.442665
# 9                                           0.441428
#
#    DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 0                                           1.696670
# 1                                           1.734281
# 2                                           1.791189
# 3                                           1.776779
# 4                                           1.712986
# 5                                           1.738272
# 6                                           1.778098
# 7                                           1.781815
# 8                                           1.729402
# 9                                           1.850988

# %%
data.shape,data.size
# Out:
# ((6840, 10), 68400)

# %%
data.set_axis(['country','year','scgizophrenia','bipolar_disorder','eating_disorder','anxiety','drug_use','Depressive_disorders','Alchohol_use','mental_fitness'],inplace=True,axis='columns')

# %%
data.head(10)
# Out:
#        country  year  scgizophrenia  bipolar_disorder  eating_disorder  \
# 0  Afghanistan  1990       0.228979          0.721207         0.131001
# 1  Afghanistan  1991       0.228120          0.719952         0.126395
# 2  Afghanistan  1992       0.227328          0.718418         0.121832
# 3  Afghanistan  1993       0.226468          0.717452         0.117942
# 4  Afghanistan  1994       0.225567          0.717012         0.114547
# 5  Afghanistan  1995       0.224713          0.716686         0.111129
# 6  Afghanistan  1996       0.223690          0.716388         0.107786
# 7  Afghanistan  1997       0.222424          0.716143         0.103931
# 8  Afghanistan  1998       0.221129          0.716139         0.100343
# 9  Afghanistan  1999       0.220065          0.716323         0.097946
#
#     anxiety  drug_use  Depressive_disorders  Alchohol_use  mental_fitness
# 0  4.835127  0.454202              5.125291      0.444036        1.696670
# 1  4.821765  0.447112              5.116306      0.444250        1.734281
# 2  4.801434  0.441190              5.106558      0.445501        1.791189
# 3  4.789363  0.435581              5.100328      0.445958        1.776779
# 4  4.784923  0.431822              5.099424      0.445779        1.712986
# 5  4.780851  0.428578              5.098495      0.445422        1.738272
# 6  4.777272  0.426393              5.100580      0.444837        1.778098
# 7  4.775242  0.423720              5.105474      0.443938        1.781815
# 8  4.777377  0.422491              5.113707      0.442665        1.729402
# 9  4.782067  0.421215              5.120480      0.441428        1.850988

# %% [markdown]
# VISUALIZATION

# %%
plt.figure(figsize=(14,8))
sns.heatmap(data.corr(),annot=True,cmap='Reds')
plt.show()

# %% [raw]
# PAIR WISE RELATIONSHIPS

# %%
sns.pairplot(data,corner=True)
plt.show()

# %%
mean=data['mental_fitness'].mean()
mean
# Out:
# 4.818061811758918

# %%
fig=px.pie(data,values='mental_fitness',names='year')
fig.show()
# Out:
# <div>                            <div id="c987fac1-3d9b-4b8c-8728-92884db7cae0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c987fac1-3d9b-4b8c-8728-92884db7cae0")) {                    Plotly.newPlot(                        "c987fac1-3d9b-4b8c-8728-92884db7cae0",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"year=%{label}<br>mental_fitness=%{value}<extra></extra>","labels":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998, ...

# %%
fig=px.line(data,x='year',y='mental_fitness',color='country',markers=True,color_discrete_sequence=['red','blue'],template='plotly_dark')

# %%
fig.show()
# Out:
# <div>                            <div id="c847c4ca-4e8a-419f-9bcc-539ee989bc7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c847c4ca-4e8a-419f-9bcc-539ee989bc7e")) {                    Plotly.newPlot(                        "c847c4ca-4e8a-419f-9bcc-539ee989bc7e",                        [{"hovertemplate":"country=Afghanistan<br>year=%{x}<br>mental_fitness=%{y}<extra></extra>","legendgroup":"Afghanistan","line":{"color":"red","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Afghanistan","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[1.696670483,1.734281366,1.79118945,1.776779315,1.712985931,1.738271645,1.778097813,1.781815481,1.729402324,1.850987749,1.893882125,1.963984243,2.090646151,2.240706644,2.360176454,2.47026111,2.558329138,2.674110194,2.811498985,2.95453609,3.082018702,3.21111457,3.311808806,3.431007766,3.444342145,3.460077381,3.505516638,3.729269234,3.817516855,3.991275425],"yaxis":"y","type":"scattergl"},{"hovertemplate":"country=African Region (WHO)<br>year=%{x}<br>mental_fitness=%{y}<extra></extra>","legendgroup":"African Region (WHO)","line":{"color":"blue","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"African Region (WHO)","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[1.417621379,1.433123548,1.448188434,1.457416191,1.378090242,1.475971225,1.482366583,1.501319427,1.521216392,1.539360469,1.56487334,1.604127032,1.636612308,1.673229173,1.722157457,1.778987045,1.843940803,1.91637155,1.991070719,2.06508151,2.149122407,2.234862224,2.323804619,2.409962721,2.494148088,2.596121328,2.705125844,2.82468727,2.953840317,3.069141885],"yaxis":"y","type":"scattergl"},{"hovertemplate":"country=Albania<br>year=%{x}<br>mental_fitness=%{y}<extra></extra>","legendgroup":"Albania","line":{"color":"red","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Albania","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[4.34094201,4.321944824,4.434127878,4.555623407,4.716930074,4.803974816,4.862896393,4.359075829,5.051468837,5.107101819,5.199095469,5.397503662,5.427811366,5.382409728,5.427353414,5.544826978,5.713607095,5.854137468,5.827382698,5.898417871,5.884421679,5.819405227,5.778056289,5.728457791,5.637052407,5.548307297,5.494031145,5.437396969,5.396927743,5.350384824],"yaxis":"y","type":"scattergl"},{"hovertemplate":"country=Algeria<br>year=%{x}<br>mental_fitness=%{y}<extra></extra>","legendgroup":"Algeria","line":{"color":"blue","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Algeria","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[4.346284525,4.558152561,4.730693789,4.902382758,5.022762426,5.19236074,5.460332883,5.505331209,5.729460904,5.99445686,6.108074368,6.279749075,6.441811426,6.522382255,6.755145867,6.876675285,6.96664495,7.033546023,7.111770567,7.162919498,7.249127347,7.29194616,7.355719796,7.391921781,7.410854159,7.45699283,7.545495557,7.632565163,7.694053419,7.80709701],"yaxis":"y","type":"scattergl"},{"hovertemplate":"country=American Samoa<br>year=%{x}<br>mental_fitness=%{y}<extra></extra>","legendgroup":"American Samoa","line":{"color":"red","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Ameri ...

# %%
df=data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6840 entries, 0 to 6839
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   country               6840 non-null   object
#  1   year                  6840 non-null   int64
#  2   scgizophrenia         6840 non-null   float64
#  3   bipolar_disorder      6840 non-null   float64
#  4   eating_disorder       6840 non-null   float64
#  5   anxiety               6840 non-null   float64
#  6   drug_use              6840 non-null   float64
#  7   Depressive_disorders  6840 non-null   float64
#  8   Alchohol_use          6840 non-null   float64
#  9   mental_fitness        6840 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 587.8+ KB

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
for i in df.columns:
    if df[i].dtype=='object':
        df[i]=l.fit_transform(df[i])

# %%
df.shape
# Out:
# (6840, 10)

# %%
x=df.drop('mental_fitness',axis=1)
y=df['mental_fitness']
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=20,random_state=2)

# %%
print('xtrain',xtrain.shape)
print('xtesrt',xtest.shape)
print('\n ytarin',ytrain.shape)
print('ytest',ytest.shape)
# Out:
# xtrain (6820, 9)
# xtesrt (20, 9)
#
#  ytarin (6820,)
# ytest (20,)

# %% [raw]
# MODEL TRAINING

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
lr=LinearRegression()
lr.fit(xtrain,ytrain)
ytrain_pred = lr.predict(xtrain)
mse=mean_squared_error(ytrain,ytrain_pred)
rmse=(np.sqrt(mean_squared_error(ytrain,ytrain_pred)))
r2=r2_score(ytrain,ytrain_pred)
print('The linear Regression model performance for training set')
print('.........................................................')
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The linear Regression model performance for training set
# .........................................................
# MSE is 1.3399913708491948
# RMSE is 1.1575799630475618
# R2 score is 0.7453536322758918

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(xtrain,ytrain)
ytrain_pred = rf.predict(xtrain)
mse=mean_squared_error(ytrain,ytrain_pred)
rmse=(np.sqrt(mean_squared_error(ytrain,ytrain_pred)))
r2=r2_score(ytrain,ytrain_pred)
print('The Random Forest Regression model performance for training set')
print('.........................................................')
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The Random Forest Regression model performance for training set
# .........................................................
# MSE is 0.0036390787069564743
# RMSE is 0.06032477689106255
# R2 score is 0.9993084446700569

# %% [markdown]
# EVALUATION
# comparing values of 2 models above mentioned

# %%
ytest_pred=lr.predict(xtest)
mse=mean_squared_error(ytest,ytest_pred)
rmse=(np.sqrt(mean_squared_error(ytest,ytest_pred)))
r2=r2_score(ytest,ytest_pred)
print('The linear Regression model performance for training set')
print('.........................................................')
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
ytest_pred=rf.predict(xtest)
mse=mean_squared_error(ytest,ytest_pred)
rmse=(np.sqrt(mean_squared_error(ytest,ytest_pred)))
r2=r2_score(ytest,ytest_pred)
print('The Random Forest Regression model performance for training set')
print('.........................................................')
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The linear Regression model performance for training set
# .........................................................
# MSE is 0.9579258617925465
# RMSE is 0.9787368705594709
# R2 score is 0.8132599812607347
# The Random Forest Regression model performance for training set
# .........................................................
# MSE is 0.009789655529351512
# RMSE is 0.09894268810453612
# R2 score is 0.9980915846101273
